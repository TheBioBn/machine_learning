# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn import datasets,linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv('house_prices1.csv')

# %%
df=(df-df.min())/(df.max()-df.min())
data_x = df['house age'].values.reshape(-1,1)
data_y = df['house price of unit area'].values.reshape(-1,1)
train_x, test_x, train_y, test_y = train_test_split(
    data_x, data_y, test_size=0.25, shuffle = False)

# %%
def predict(theta0, theta1, x):
    return theta0 + theta1*x
#mean squared error
def mse(X,y,theta0,theta1):
    return np.mean((predict(theta0, theta1, X) - y)**2)

# %%
def sgd(x, y, theta0, theta1, learning_r, iterations):
    for i in range(iterations):
        theta0_prev = theta0
        theta0 = theta0_prev - learning_r*np.mean(2*(y - (theta0 + theta1*x)))
        theta1_prev = theta1
        theta1 = theta1_prev - learning_r*np.mean(2*x*(y - (theta0 + theta1*x)))
        print(mse(x,y,theta0,theta1))
    return theta0, theta1

# %%
sgd(train_x, train_y, -1, -0.5, -0.1, 50)
# Out:
# 1.3210162703627977
# 0.7899948201449716
# 0.4744259772380362
# 0.2868893185533709
# 0.17543638486151156
# 0.10919725937491653
# 0.06982760082748217
# 0.04642622311799644
# 0.03251496485731513
# 0.02424402793485827
# 0.019325524945145053
# 0.01639975049658393
# 0.014658591204532003
# 0.013621736643758127
# 0.013003690636118937
# 0.012634740097154129
# 0.01241398816960402
# 0.012281441814279977
# 0.012201422854432743
# 0.012152708331083955
# 0.012122670069385012
# 0.012103791049488275
# 0.012091594420250578
# 0.012083412159686988
# 0.012077652842035205
# 0.01207336611444899
# 0.01206998358371902
# 0.012067164604850683
# 0.012064704461873618
# 0.0120624796670967
# 0.01206041535018506
# 0.012058465798810215
# 0.012056602833543135
# 0.012054808852724364
# 0.012053072663537003
# 0.012051386977237238
# 0.012049746899767873
# 0.012048149018806973
# 0.012046590849009138
# 0.012045070492972198
# 0.012043586432587553
# 0.012042137399540848
# 0.012040722294121297
# 0.01203934013371024
# 0.012037990019647976
# 0.012036671115587783
# 0.012035382633108238
# 0.012034123821968813
# 0.012032893963376996
# 0.012031692365237899
# (0.3006676652632574, -0.06768737281945963)

# %%
2429.7484249999998*-0.01
# Out:
# -24.297484249999997

# %%
mse(train_x, train_y, -1, -0.5)
# Out:
# 2.2146048319392335

# %%
x = np.linspace(-5,5,100)
y = -0.067*x+0.3
plt.plot(x, y, '-r', label='y=2x+1')
plt.title('Graph of y=2x+1')
plt.xlabel('x', color='#1C2833')
plt.ylabel('y', color='#1C2833')
plt.legend(loc='upper left')
plt.grid()
plt.show()
sns.regplot(x='house age',y='house price of unit area',data=df)
plt.show()
